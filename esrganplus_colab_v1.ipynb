# %% [markdown]
# <a href="https://colab.research.google.com/github/z3n47/ESRGANplus-YT/blob/main/esrganplus_colab_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/z3n47/ESRGANplus-YT.git
# Out:
# Cloning into 'ESRGANplus-YT'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 150 (delta 0), reused 7 (delta 0), pack-reused 139 (from 1)
# Receiving objects: 100% (150/150), 296.78 MiB | 27.50 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Updating files: 100% (120/120), done.

# %%
cd ESRGANplus-YT/
# Out:
# /content/ESRGANplus-YT

# %%
ls
# Out:
# ESRGANplus/

# %%
cd ESRGANplus
# Out:
# /content/ESRGANplus-YT/ESRGANplus

# %%
ls
# Out:
# cal_metrics.py  experiments/  LICENSE   metrics_results.txt  test_image/
# codes/          figures/      metrics/  README.md

# %%
# !python test_image/test.py test_image/pretrained_models/nESRGANplus.pth
# Out:
# Model path test_image/pretrained_models/nESRGANplus.pth.
# Testing...
# 1 0804x4
# [ WARN:0@7.044] global loadsave.cpp:1063 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# 2 Dora1
# 3 0810x4
# 4 baby
# 5 bird
# 6 0830x4
# 7 0806x4
# 8 0807x4
# 9 butterfly
# 10 head
# 11 0808x4
# 12 0805x4
# 13 0801x4
# 14 Eminem_1
# 15 0802x4
# 16 hitman1
# 17 Ghost_of_Tsushima
# 18 0809x4
# 19 woman
# 20 0803x4

# %%
# !python cal_metrics.py
# Out:
# Project root: /content/ESRGANplus-YT/ESRGANplus
# Results directory: /content/ESRGANplus-YT/ESRGANplus/test_image/results
# HR directory: /content/ESRGANplus-YT/ESRGANplus/test_image/HR
# Checking directories:
# Results: /content/ESRGANplus-YT/ESRGANplus/test_image/results
# HR: /content/ESRGANplus-YT/ESRGANplus/test_image/HR
#
# Found 20 result files and 10 HR files
#
# Processing 0801x4_rlt.png vs 0801.png
# PSNR: 25.7783 dB, SSIM: 0.7956
#
# Processing 0802x4_rlt.png vs 0802.png
# PSNR: 29.3634 dB, SSIM: 0.7651
#
# Processing 0803x4_rlt.png vs 0803.png
# PSNR: 35.0634 dB, SSIM: 0.8923
#
# Processing 0804x4_rlt.png vs 0804.png
# PSNR: 24.6910 dB, SSIM: 0.7248
#
# Processing 0805x4_rlt.png vs 0805.png
# PSNR: 25.2492 dB, SSIM: 0.6879
#
# Processing 0806x4_rlt.png vs 0806.png
# PSNR: 25.3316 dB, SSIM: 0.7978
#
# Processing 0807x4_rlt.png vs 0807.png
# PSNR: 16.4921 dB, SSIM: 0.3892
#
# Processing 0808x4_rlt.png vs 0808.png
# PSNR: 23.0400 dB, SSIM: 0.7282
#
# ...
